# %%
import random

# %%
def build_dictionary(dictionary_file_location):
    """
    Builds a dictionary mapping word lengths to lists of words with that length.
    """
    word_dict = {}
    with open(dictionary_file_location, "r") as text_file:
        for line in text_file:
            word = line.strip()
            word_length = len(word)
            if word_length not in word_dict:
                word_dict[word_length] = []
            word_dict[word_length].append(word)
    return word_dict


def choose_secret_word(word_dict):
    """
    Selects a random word from the dictionary based on frequency distribution.
    """
    total_words = sum(len(words) for words in word_dict.values())
    word_length = random.choices(list(word_dict.keys()), weights=[len(words) / total_words for words in word_dict.values()])[0]
    return random.choice(word_dict[word_length])


def calculate_letter_entropy(displayed_word, word_dict):
    """
    Calculates the entropy of each letter based on remaining possible words.
    """
    letter_entropies = {}
    for word_length, words in word_dict.items():
        if len(displayed_word) == word_length:
            for word in words:
                for letter in word:
                    if letter not in displayed_word and letter not in letter_entropies:
                        letter_entropies[letter] = 0
                    elif letter not in displayed_word:
                        letter_entropies[letter] += 1 / len(word)  # Average uncertainty reduction

    # Normalize entropies for comparison
    total_entropy = sum(entropies for entropies in letter_entropies.values())
    if total_entropy > 0:
        for letter, entropy in letter_entropies.items():
            letter_entropies[letter] /= total_entropy
    return letter_entropies


def make_best_guess(displayed_word, word_dict):
    """
    Finds the letter with the highest entropy based on remaining possibilities.
    """
    letter_entropies = calculate_letter_entropy(displayed_word, word_dict)
    return max(letter_entropies, key=letter_entropies.get)


def is_letter_present(guess, secret_word):
    """
    Checks if the guessed letter is present in the secret word.
    """
    return guess.lower() in secret_word.lower()


def update_word_display(guess, secret_word, displayed_word):
    """
    Updates the displayed word with correctly guessed letters.
    """
    updated_word = ""
    for idx, letter in enumerate(secret_word):
        if displayed_word[idx] == "_" and letter.lower() == guess.lower():
            updated_word += guess
        else:
            updated_word += displayed_word[idx]
    return updated_word


def update_possible_words(displayed_word, guess, is_correct, word_dict):
    """
    Updates the list of possible words based on the guess and its outcome.

    Args:
        displayed_word: The current display of the word with underscores.
        guess: The letter guessed by the user.
        is_correct: True if the guess was correct, False otherwise.
        word_dict: Dictionary of word lengths and corresponding word lists.

    Returns:
        An updated dictionary with word lengths as keys and filtered word lists as values.
    """

    # Create a copy of the word dictionary to avoid modifying the original
    updated_word_dict = {word_length: words.copy() for word_length, words in word_dict.items()}

    # Filter word lists based on correct/incorrect guess
    if is_correct:
        # Keep words containing the guessed letter at the correct positions
        for word_length, words in updated_word_dict.items():
            if len(displayed_word) == word_length:
                updated_word_dict[word_length] = [word for word in words if all(displayed_word[idx] == word[idx] or displayed_word[idx] == "_" for idx in range(word_length))]
    else:
        # Keep words NOT containing the guessed letter
        for word_length, words in updated_word_dict.items():
            if len(displayed_word) == word_length:
                updated_word_dict[word_length] = [word for word in words if guess not in word]

    return updated_word_dict

def start_game(word_dict, num_games):
    """
    Runs the Hangman game multiple times and calculates accuracy.
    """

    total_success = 0
    for _ in range(num_games):
        secret_word = choose_secret_word(word_dict)
        displayed_word = "_" * len(secret_word)
        max_guesses = 6
        word_dict = {word_length: words.copy() for word_length, words in word_dict.items()}  # Create a copy for each game

        while True:
            if displayed_word == secret_word:
                total_success += 1
                print(f"You won! The word was {secret_word}.")
                break
            if max_guesses == 0:
                print(f"You lost! The word was {secret_word}.")
                break

            guess = make_best_guess(displayed_word, word_dict)

            if is_letter_present(guess, secret_word):
                print(f"Good guess! '{guess}' is in the word.")
                displayed_word = update_word_display(guess, secret_word, displayed_word)
            else:
                print(f"Oops! '{guess}' is not in the word.")
                max_guesses -= 1

            word_dict = update_possible_words(displayed_word, guess, is_letter_present(guess, secret_word), word_dict)

            print(f"Current word: {displayed_word}")
            print(f"You have {max_guesses} guesses left.")

    accuracy = (total_success / num_games) * 100
    print(f"Accuracy: {accuracy:.2f}%")

    return accuracy

# %%
dictionary_file_location = "RandomWords.txt"

# %%
word_dict = build_dictionary(dictionary_file_location)

# %%
num_games = 1000  # Play the game 100 times

start_game(word_dict, num_games)
# Out:
# Streaming output truncated to the last 5000 lines.
# Current word: c_c__tri_et___enetrinitr__ine
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: cyc__tri_et_y_enetrinitr__ine
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: cycl_tri_et_ylenetrinitr__ine
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: cycl_trimet_ylenetrinitr_mine
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: cyclotrimet_ylenetrinitr_mine
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: cyclotrimethylenetrinitr_mine
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: cyclotrimethylenetrinitramine
# You have 6 guesses left.
# You won! The word was cyclotrimethylenetrinitramine.
# Good guess! 'r' is in the word.
# Current word: r_____r
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: re___er
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: res__er
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: resa_er
# You have 6 guesses left.
# Good guess! 'w' is in the word.
# Current word: resawer
# You have 6 guesses left.
# You won! The word was resawer.
# Good guess! 's' is in the word.
# Current word: s_______________ss
# You have 6 guesses left.
# Good guess! 'b' is in the word.
# Current word: s_b_____b_______ss
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: s_ba____ba______ss
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: s_bapp__ba______ss
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: s_bapp__ba___e_ess
# You have 6 guesses left.
# Good guess! 'u' is in the word.
# Current word: subapp__ba___e_ess
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: subappr_ba___e_ess
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: subapproba___e_ess
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: subapprobat__e_ess
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: subapprobati_e_ess
# You have 6 guesses left.
# Good guess! 'v' is in the word.
# Current word: subapprobative_ess
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: subapprobativeness
# You have 6 guesses left.
# You won! The word was subapprobativeness.
# Good guess! 'd' is in the word.
# Current word: d___
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: de__
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: des_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: desi
# You have 6 guesses left.
# You won! The word was desi.
# Good guess! 'u' is in the word.
# Current word: _u____u____u_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: _u_t_tu____u_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: _u_titu_i__u_
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: mu_titu_i__u_
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: multitu_i__u_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: multitudi__u_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: multitudin_u_
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: multitudinou_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: multitudinous
# You have 6 guesses left.
# You won! The word was multitudinous.
# Good guess! 'e' is in the word.
# Current word: e_e____e__e______________
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: ele____e__e___l_________l
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: elec___e_ce___l_______c_l
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: elec___e_ce__al___a___cal
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: elec_r_e_ce__al__ra___cal
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: elec_roe_ce__alo_ra___cal
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: elec_roe_cep_alo_rap__cal
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: elec_roe_cephalo_raph_cal
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: electroe_cephalo_raph_cal
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: electroencephalo_raph_cal
# You have 6 guesses left.
# Good guess! 'g' is in the word.
# Current word: electroencephalograph_cal
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: electroencephalographical
# You have 6 guesses left.
# You won! The word was electroencephalographical.
# Good guess! 'e' is in the word.
# Current word: _e__e_e______e_e__e_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: _e__ese______e_esses
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: re_rese______e_esses
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: re_resen_____enesses
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: re_resent_t__enesses
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: represent_t__enesses
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: representat__enesses
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: representati_enesses
# You have 6 guesses left.
# Good guess! 'v' is in the word.
# Current word: representativenesses
# You have 6 guesses left.
# You won! The word was representativenesses.
# Good guess! 'o' is in the word.
# Current word: __o_o_
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: p_o_o_
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: pro_o_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: proto_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: proton
# You have 6 guesses left.
# You won! The word was proton.
# Good guess! 'e' is in the word.
# Current word: e_e____e__e______________
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: ele____e__e___l_________l
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: elec___e_ce___l_______c_l
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: elec___e_ce__al___a___cal
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: elec_r_e_ce__al__ra___cal
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: elec_roe_ce__alo_ra___cal
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: elec_roe_cep_alo_rap__cal
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: elec_roe_cephalo_raph_cal
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: electroe_cephalo_raph_cal
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: electroencephalo_raph_cal
# You have 6 guesses left.
# Good guess! 'g' is in the word.
# Current word: electroencephalograph_cal
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: electroencephalographical
# You have 6 guesses left.
# You won! The word was electroencephalographical.
# Good guess! 'm' is in the word.
# Current word: m_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: ms
# You have 6 guesses left.
# You won! The word was ms.
# Good guess! 'p' is in the word.
# Current word: p__________p____p__
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: pa___a_____p___ap__
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: pa__oa____opo__ap__
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: pa__oa__h_opo__aph_
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: pa__oa__hropo_raph_
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: pal_oa__hropo_raph_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: paleoa__hropo_raph_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: paleoan_hropo_raph_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: paleoanthropo_raph_
# You have 6 guesses left.
# Good guess! 'g' is in the word.
# Current word: paleoanthropograph_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: paleoanthropography
# You have 6 guesses left.
# You won! The word was paleoanthropography.
# Good guess! 'u' is in the word.
# Current word: _u____u____u_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: _u_t_tu____u_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: _u_titu_i__u_
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: mu_titu_i__u_
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: multitu_i__u_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: multitudi__u_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: multitudin_u_
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: multitudinou_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: multitudinous
# You have 6 guesses left.
# You won! The word was multitudinous.
# Good guess! 'e' is in the word.
# Current word: e_e____e__e______________
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: ele____e__e___l_________l
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: elec___e_ce___l_______c_l
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: elec___e_ce__al___a___cal
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: elec_r_e_ce__al__ra___cal
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: elec_roe_ce__alo_ra___cal
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: elec_roe_cep_alo_rap__cal
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: elec_roe_cephalo_raph_cal
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: electroe_cephalo_raph_cal
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: electroencephalo_raph_cal
# You have 6 guesses left.
# Good guess! 'g' is in the word.
# Current word: electroencephalograph_cal
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: electroencephalographical
# You have 6 guesses left.
# You won! The word was electroencephalographical.
# Good guess! 'o' is in the word.
# Current word: _____o____o_____
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: _____on___on____
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: _____ona__ona___
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: _____ona__onall_
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: p____ona__onall_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: ps___ona__onall_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: pse__ona__onall_
# You have 6 guesses left.
# Good guess! 'u' is in the word.
# Current word: pseu_ona__onall_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: pseudona__onall_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: pseudonat_onall_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: pseudonationall_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: pseudonationally
# You have 6 guesses left.
# You won! The word was pseudonationally.
# Good guess! 'e' is in the word.
# Current word: _e______e
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: de______e
# You have 6 guesses left.
# Good guess! 'f' is in the word.
# Current word: def_____e
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: defl____e
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: deflo___e
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: deflor__e
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: deflora_e
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: deflorate
# You have 6 guesses left.
# You won! The word was deflorate.
# Good guess! 't' is in the word.
# Current word: _____t____t______t____t______
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: _____t_i__t______t_i_it___i__
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: _____t_i_et___e_et_i_it___i_e
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: _____tri_et___e_etri_itr__i_e
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: _____tri_et___enetrinitr__ine
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: c_c__tri_et___enetrinitr__ine
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: cyc__tri_et_y_enetrinitr__ine
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: cycl_tri_et_ylenetrinitr__ine
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: cycl_trimet_ylenetrinitr_mine
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: cyclotrimet_ylenetrinitr_mine
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: cyclotrimethylenetrinitr_mine
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: cyclotrimethylenetrinitramine
# You have 6 guesses left.
# You won! The word was cyclotrimethylenetrinitramine.
# Good guess! 'a' is in the word.
# Current word: a_a__
# You have 6 guesses left.
# Good guess! 'w' is in the word.
# Current word: awa__
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: away_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: aways
# You have 6 guesses left.
# You won! The word was aways.
# Good guess! 'm' is in the word.
# Current word: m_______
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: ma______
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: man_____
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: mand____
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: mande___
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: mandel__
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: mandeli_
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: mandelic
# You have 6 guesses left.
# You won! The word was mandelic.
# Good guess! 'o' is in the word.
# Current word: _____o____o_____
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: _____on___on____
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: _____ona__ona___
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: _____ona__onall_
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: p____ona__onall_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: ps___ona__onall_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: pse__ona__onall_
# You have 6 guesses left.
# Good guess! 'u' is in the word.
# Current word: pseu_ona__onall_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: pseudona__onall_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: pseudonat_onall_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: pseudonationall_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: pseudonationally
# You have 6 guesses left.
# You won! The word was pseudonationally.
# Good guess! 'p' is in the word.
# Current word: p_____p_________p______
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: p_____p__l______p___ll_
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: p____op__l_____op___ll_
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: p____oph_l___h_op___ll_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: p____ophil___h_opi__ll_
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: p____ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: ps___ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: pse__ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'u' is in the word.
# Current word: pseu_ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: pseudophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: pseudophilan_h_opi_all_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: pseudophilanth_opi_all_
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: pseudophilanthropi_all_
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: pseudophilanthropicall_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: pseudophilanthropically
# You have 6 guesses left.
# You won! The word was pseudophilanthropically.
# Good guess! 'a' is in the word.
# Current word: _a______a_____a______a______
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: _al_____a_____al_____a____l_
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: hal_____a____hal_____a____l_
# You have 6 guesses left.
# Good guess! 'f' is in the word.
# Current word: half____a____half____a____l_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: halfe___a____halfe___a____l_
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: halfem__a____halfem__a____l_
# You have 6 guesses left.
# Good guess! 'b' is in the word.
# Current word: halfemb_a____halfemb_a____l_
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: halfembra____halfembra____l_
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: halfembrac___halfembrac___l_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: halfembraci__halfembraci__l_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: halfembracin_halfembracin_l_
# You have 6 guesses left.
# Good guess! 'g' is in the word.
# Current word: halfembracinghalfembracingl_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: halfembracinghalfembracingly
# You have 6 guesses left.
# You won! The word was halfembracinghalfembracingly.
# Good guess! 'f' is in the word.
# Current word: f__
# You have 6 guesses left.
# Good guess! 'g' is in the word.
# Current word: fg_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: fgn
# You have 6 guesses left.
# You won! The word was fgn.
# Good guess! 'p' is in the word.
# Current word: p_____p_________p______
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: p_____p__l______p___ll_
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: p____op__l_____op___ll_
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: p____oph_l___h_op___ll_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: p____ophil___h_opi__ll_
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: p____ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: ps___ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: pse__ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'u' is in the word.
# Current word: pseu_ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: pseudophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: pseudophilan_h_opi_all_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: pseudophilanth_opi_all_
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: pseudophilanthropi_all_
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: pseudophilanthropicall_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: pseudophilanthropically
# You have 6 guesses left.
# You won! The word was pseudophilanthropically.
# Good guess! 'a' is in the word.
# Current word: a_a__
# You have 6 guesses left.
# Good guess! 'w' is in the word.
# Current word: awa__
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: away_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: aways
# You have 6 guesses left.
# You won! The word was aways.
# Good guess! 'p' is in the word.
# Current word: p___p_______
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: pe__p__e____
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: pe_ip__e_i__
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: pe_ip_teti__
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: perip_teti__
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: peripateti__
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: peripatetic_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: peripatetics
# You have 6 guesses left.
# You won! The word was peripatetics.
# Good guess! 'k' is in the word.
# Current word: k
# You have 6 guesses left.
# You won! The word was k.
# Good guess! 'r' is in the word.
# Current word: r_____r
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: re___er
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: res__er
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: resa_er
# You have 6 guesses left.
# Good guess! 'w' is in the word.
# Current word: resawer
# You have 6 guesses left.
# You won! The word was resawer.
# Good guess! 'e' is in the word.
# Current word: _e__e_e______e_e__e_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: _e__ese______e_esses
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: re_rese______e_esses
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: re_resen_____enesses
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: re_resent_t__enesses
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: represent_t__enesses
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: representat__enesses
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: representati_enesses
# You have 6 guesses left.
# Good guess! 'v' is in the word.
# Current word: representativenesses
# You have 6 guesses left.
# You won! The word was representativenesses.
# Good guess! 'f' is in the word.
# Current word: f__
# You have 6 guesses left.
# Good guess! 'g' is in the word.
# Current word: fg_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: fgn
# You have 6 guesses left.
# You won! The word was fgn.
# Good guess! 'p' is in the word.
# Current word: p___p_______
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: pe__p__e____
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: pe_ip__e_i__
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: pe_ip_teti__
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: perip_teti__
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: peripateti__
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: peripatetic_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: peripatetics
# You have 6 guesses left.
# You won! The word was peripatetics.
# Good guess! 'm' is in the word.
# Current word: m_______
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: ma______
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: man_____
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: mand____
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: mande___
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: mandel__
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: mandeli_
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: mandelic
# You have 6 guesses left.
# You won! The word was mandelic.
# Good guess! 'a' is in the word.
# Current word: _a______a_____a______a______
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: _al_____a_____al_____a____l_
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: hal_____a____hal_____a____l_
# You have 6 guesses left.
# Good guess! 'f' is in the word.
# Current word: half____a____half____a____l_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: halfe___a____halfe___a____l_
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: halfem__a____halfem__a____l_
# You have 6 guesses left.
# Good guess! 'b' is in the word.
# Current word: halfemb_a____halfemb_a____l_
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: halfembra____halfembra____l_
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: halfembrac___halfembrac___l_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: halfembraci__halfembraci__l_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: halfembracin_halfembracin_l_
# You have 6 guesses left.
# Good guess! 'g' is in the word.
# Current word: halfembracinghalfembracingl_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: halfembracinghalfembracingly
# You have 6 guesses left.
# You won! The word was halfembracinghalfembracingly.
# Good guess! 'm' is in the word.
# Current word: m_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: ms
# You have 6 guesses left.
# You won! The word was ms.
# Good guess! 'a' is in the word.
# Current word: _a______a_____a______a______
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: _al_____a_____al_____a____l_
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: hal_____a____hal_____a____l_
# You have 6 guesses left.
# Good guess! 'f' is in the word.
# Current word: half____a____half____a____l_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: halfe___a____halfe___a____l_
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: halfem__a____halfem__a____l_
# You have 6 guesses left.
# Good guess! 'b' is in the word.
# Current word: halfemb_a____halfemb_a____l_
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: halfembra____halfembra____l_
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: halfembrac___halfembrac___l_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: halfembraci__halfembraci__l_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: halfembracin_halfembracin_l_
# You have 6 guesses left.
# Good guess! 'g' is in the word.
# Current word: halfembracinghalfembracingl_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: halfembracinghalfembracingly
# You have 6 guesses left.
# You won! The word was halfembracinghalfembracingly.
# Good guess! 'e' is in the word.
# Current word: _e__e_e______e_e__e_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: _e__ese______e_esses
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: re_rese______e_esses
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: re_resen_____enesses
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: re_resent_t__enesses
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: represent_t__enesses
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: representat__enesses
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: representati_enesses
# You have 6 guesses left.
# Good guess! 'v' is in the word.
# Current word: representativenesses
# You have 6 guesses left.
# You won! The word was representativenesses.
# Good guess! 'm' is in the word.
# Current word: m_______
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: ma______
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: man_____
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: mand____
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: mande___
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: mandel__
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: mandeli_
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: mandelic
# You have 6 guesses left.
# You won! The word was mandelic.
# Good guess! 'u' is in the word.
# Current word: _u____u____u_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: _u_t_tu____u_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: _u_titu_i__u_
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: mu_titu_i__u_
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: multitu_i__u_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: multitudi__u_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: multitudin_u_
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: multitudinou_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: multitudinous
# You have 6 guesses left.
# You won! The word was multitudinous.
# Good guess! 't' is in the word.
# Current word: _____t____t______t____t______
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: _____t_i__t______t_i_it___i__
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: _____t_i_et___e_et_i_it___i_e
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: _____tri_et___e_etri_itr__i_e
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: _____tri_et___enetrinitr__ine
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: c_c__tri_et___enetrinitr__ine
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: cyc__tri_et_y_enetrinitr__ine
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: cycl_tri_et_ylenetrinitr__ine
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: cycl_trimet_ylenetrinitr_mine
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: cyclotrimet_ylenetrinitr_mine
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: cyclotrimethylenetrinitr_mine
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: cyclotrimethylenetrinitramine
# You have 6 guesses left.
# You won! The word was cyclotrimethylenetrinitramine.
# Good guess! 'l' is in the word.
# Current word: _______l___ll_____ll_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: _y_____ly_yll_____lly
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: _yp__p_ly_yll_____lly
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: _yp__p_ly_ylla___ally
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: hyp__p_ly_ylla___ally
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: hype_p_ly_ylla___ally
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: hyperp_ly_ylla___ally
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: hyperpoly_ylla___ally
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: hyperpolysylla___ally
# You have 6 guesses left.
# Good guess! 'b' is in the word.
# Current word: hyperpolysyllab__ally
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: hyperpolysyllabi_ally
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: hyperpolysyllabically
# You have 6 guesses left.
# You won! The word was hyperpolysyllabically.
# Good guess! 'l' is in the word.
# Current word: _______l___ll_____ll_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: _y_____ly_yll_____lly
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: _yp__p_ly_yll_____lly
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: _yp__p_ly_ylla___ally
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: hyp__p_ly_ylla___ally
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: hype_p_ly_ylla___ally
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: hyperp_ly_ylla___ally
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: hyperpoly_ylla___ally
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: hyperpolysylla___ally
# You have 6 guesses left.
# Good guess! 'b' is in the word.
# Current word: hyperpolysyllab__ally
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: hyperpolysyllabi_ally
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: hyperpolysyllabically
# You have 6 guesses left.
# You won! The word was hyperpolysyllabically.
# Good guess! 'i' is in the word.
# Current word: i_______i_i_i__
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: in____n_i_i_i__
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: ine___n_i_i_i__
# You have 6 guesses left.
# Good guess! 'x' is in the word.
# Current word: inex__n_i_i_i__
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: inexp_n_i_i_i__
# You have 6 guesses left.
# Good guess! 'u' is in the word.
# Current word: inexpun_i_i_i__
# You have 6 guesses left.
# Good guess! 'g' is in the word.
# Current word: inexpungi_i_i__
# You have 6 guesses left.
# Good guess! 'b' is in the word.
# Current word: inexpungibi_i__
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: inexpungibili__
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: inexpungibilit_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: inexpungibility
# You have 6 guesses left.
# You won! The word was inexpungibility.
# Good guess! 'o' is in the word.
# Current word: __o___o__o______o__o__
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: d_od__o__o______o__o__
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: d_ode_o__o_e____o__o__
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: d_ode_oc_o_ec___o__o__
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: d_ode_oc_o_ecy__o__o_y
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: d_ode_oc_o_ecys_os_o_y
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: d_ode_oc_o_ecystosto_y
# You have 6 guesses left.
# Good guess! 'u' is in the word.
# Current word: duode_oc_o_ecystosto_y
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: duodenoc_o_ecystosto_y
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: duodenocho_ecystosto_y
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: duodenocholecystosto_y
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: duodenocholecystostomy
# You have 6 guesses left.
# You won! The word was duodenocholecystostomy.
# Good guess! 'a' is in the word.
# Current word: _a______a_____a______a______
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: _al_____a_____al_____a____l_
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: hal_____a____hal_____a____l_
# You have 6 guesses left.
# Good guess! 'f' is in the word.
# Current word: half____a____half____a____l_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: halfe___a____halfe___a____l_
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: halfem__a____halfem__a____l_
# You have 6 guesses left.
# Good guess! 'b' is in the word.
# Current word: halfemb_a____halfemb_a____l_
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: halfembra____halfembra____l_
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: halfembrac___halfembrac___l_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: halfembraci__halfembraci__l_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: halfembracin_halfembracin_l_
# You have 6 guesses left.
# Good guess! 'g' is in the word.
# Current word: halfembracinghalfembracingl_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: halfembracinghalfembracingly
# You have 6 guesses left.
# You won! The word was halfembracinghalfembracingly.
# Good guess! 'u' is in the word.
# Current word: _u____u____u_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: _u_t_tu____u_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: _u_titu_i__u_
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: mu_titu_i__u_
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: multitu_i__u_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: multitudi__u_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: multitudin_u_
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: multitudinou_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: multitudinous
# You have 6 guesses left.
# You won! The word was multitudinous.
# Good guess! 'p' is in the word.
# Current word: p___p_______
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: pe__p__e____
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: pe_ip__e_i__
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: pe_ip_teti__
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: perip_teti__
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: peripateti__
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: peripatetic_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: peripatetics
# You have 6 guesses left.
# You won! The word was peripatetics.
# Good guess! 'l' is in the word.
# Current word: _l___________________ll_
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: _l_c___c___________c_ll_
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: _l_c_r_c_r____r____c_ll_
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: _l_c_r_car____ra___call_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: elec_r_car____ra___call_
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: elec_rocar__o_ra___call_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: elec_rocar_io_ra__icall_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: electrocar_io_ra__icall_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: electrocardio_ra__icall_
# You have 6 guesses left.
# Good guess! 'g' is in the word.
# Current word: electrocardiogra__icall_
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: electrocardiograp_icall_
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: electrocardiographicall_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: electrocardiographically
# You have 6 guesses left.
# You won! The word was electrocardiographically.
# Good guess! 'p' is in the word.
# Current word: p__________p____p__
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: pa___a_____p___ap__
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: pa__oa____opo__ap__
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: pa__oa__h_opo__aph_
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: pa__oa__hropo_raph_
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: pal_oa__hropo_raph_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: paleoa__hropo_raph_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: paleoan_hropo_raph_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: paleoanthropo_raph_
# You have 6 guesses left.
# Good guess! 'g' is in the word.
# Current word: paleoanthropograph_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: paleoanthropography
# You have 6 guesses left.
# You won! The word was paleoanthropography.
# Good guess! 'o' is in the word.
# Current word: _____o____o_____
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: _____on___on____
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: _____ona__ona___
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: _____ona__onall_
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: p____ona__onall_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: ps___ona__onall_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: pse__ona__onall_
# You have 6 guesses left.
# Good guess! 'u' is in the word.
# Current word: pseu_ona__onall_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: pseudona__onall_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: pseudonat_onall_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: pseudonationall_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: pseudonationally
# You have 6 guesses left.
# You won! The word was pseudonationally.
# Good guess! 'k' is in the word.
# Current word: k
# You have 6 guesses left.
# You won! The word was k.
# Good guess! 'm' is in the word.
# Current word: m_______
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: ma______
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: man_____
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: mand____
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: mande___
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: mandel__
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: mandeli_
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: mandelic
# You have 6 guesses left.
# You won! The word was mandelic.
# Good guess! 'o' is in the word.
# Current word: ____o_____o___o____o____o__
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: _y__o_y___o_y_o____o____o__
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: _y_ro_y___o_y_or___o___ro__
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: _y_ro_y_e_o_y_or___o__ero_e
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: _ydro_yde_o_y_or___o__ero_e
# You have 6 guesses left.
# Good guess! 'x' is in the word.
# Current word: _ydroxyde_oxy_or___o__ero_e
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: _ydroxydesoxy_or___os_ero_e
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: _ydroxydesoxycor__cos_ero_e
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: _ydroxydesoxycort_costero_e
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: hydroxydesoxycort_costero_e
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: hydroxydesoxycorticostero_e
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: hydroxydesoxycorticosterone
# You have 6 guesses left.
# You won! The word was hydroxydesoxycorticosterone.
# Good guess! 'e' is in the word.
# Current word: _e__e_e______e_e__e_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: _e__ese______e_esses
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: re_rese______e_esses
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: re_resen_____enesses
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: re_resent_t__enesses
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: represent_t__enesses
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: representat__enesses
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: representati_enesses
# You have 6 guesses left.
# Good guess! 'v' is in the word.
# Current word: representativenesses
# You have 6 guesses left.
# You won! The word was representativenesses.
# Good guess! 'e' is in the word.
# Current word: e_e____e__e______________
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: ele____e__e___l_________l
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: elec___e_ce___l_______c_l
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: elec___e_ce__al___a___cal
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: elec_r_e_ce__al__ra___cal
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: elec_roe_ce__alo_ra___cal
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: elec_roe_cep_alo_rap__cal
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: elec_roe_cephalo_raph_cal
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: electroe_cephalo_raph_cal
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: electroencephalo_raph_cal
# You have 6 guesses left.
# Good guess! 'g' is in the word.
# Current word: electroencephalograph_cal
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: electroencephalographical
# You have 6 guesses left.
# You won! The word was electroencephalographical.
# Good guess! 'p' is in the word.
# Current word: p_____p_________p______
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: p_____p__l______p___ll_
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: p____op__l_____op___ll_
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: p____oph_l___h_op___ll_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: p____ophil___h_opi__ll_
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: p____ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: ps___ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: pse__ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'u' is in the word.
# Current word: pseu_ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: pseudophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: pseudophilan_h_opi_all_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: pseudophilanth_opi_all_
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: pseudophilanthropi_all_
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: pseudophilanthropicall_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: pseudophilanthropically
# You have 6 guesses left.
# You won! The word was pseudophilanthropically.
# Good guess! 's' is in the word.
# Current word: s_______________ss
# You have 6 guesses left.
# Good guess! 'b' is in the word.
# Current word: s_b_____b_______ss
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: s_ba____ba______ss
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: s_bapp__ba______ss
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: s_bapp__ba___e_ess
# You have 6 guesses left.
# Good guess! 'u' is in the word.
# Current word: subapp__ba___e_ess
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: subappr_ba___e_ess
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: subapproba___e_ess
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: subapprobat__e_ess
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: subapprobati_e_ess
# You have 6 guesses left.
# Good guess! 'v' is in the word.
# Current word: subapprobative_ess
# ...
# Current word: multitu_i__u_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: multitudi__u_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: multitudin_u_
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: multitudinou_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: multitudinous
# You have 6 guesses left.
# You won! The word was multitudinous.
# Good guess! 'a' is in the word.
# Current word: a_a__
# You have 6 guesses left.
# Good guess! 'w' is in the word.
# Current word: awa__
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: away_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: aways
# You have 6 guesses left.
# You won! The word was aways.
# Good guess! 'l' is in the word.
# Current word: _______l___ll_____ll_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: _y_____ly_yll_____lly
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: _yp__p_ly_yll_____lly
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: _yp__p_ly_ylla___ally
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: hyp__p_ly_ylla___ally
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: hype_p_ly_ylla___ally
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: hyperp_ly_ylla___ally
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: hyperpoly_ylla___ally
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: hyperpolysylla___ally
# You have 6 guesses left.
# Good guess! 'b' is in the word.
# Current word: hyperpolysyllab__ally
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: hyperpolysyllabi_ally
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: hyperpolysyllabically
# You have 6 guesses left.
# You won! The word was hyperpolysyllabically.
# Good guess! 'r' is in the word.
# Current word: r_____r
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: re___er
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: res__er
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: resa_er
# You have 6 guesses left.
# Good guess! 'w' is in the word.
# Current word: resawer
# You have 6 guesses left.
# You won! The word was resawer.
# Good guess! 'f' is in the word.
# Current word: f__
# You have 6 guesses left.
# Good guess! 'g' is in the word.
# Current word: fg_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: fgn
# You have 6 guesses left.
# You won! The word was fgn.
# Good guess! 'u' is in the word.
# Current word: _u____u____u_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: _u_t_tu____u_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: _u_titu_i__u_
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: mu_titu_i__u_
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: multitu_i__u_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: multitudi__u_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: multitudin_u_
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: multitudinou_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: multitudinous
# You have 6 guesses left.
# You won! The word was multitudinous.
# Good guess! 's' is in the word.
# Current word: s_______________ss
# You have 6 guesses left.
# Good guess! 'b' is in the word.
# Current word: s_b_____b_______ss
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: s_ba____ba______ss
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: s_bapp__ba______ss
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: s_bapp__ba___e_ess
# You have 6 guesses left.
# Good guess! 'u' is in the word.
# Current word: subapp__ba___e_ess
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: subappr_ba___e_ess
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: subapproba___e_ess
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: subapprobat__e_ess
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: subapprobati_e_ess
# You have 6 guesses left.
# Good guess! 'v' is in the word.
# Current word: subapprobative_ess
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: subapprobativeness
# You have 6 guesses left.
# You won! The word was subapprobativeness.
# Good guess! 'e' is in the word.
# Current word: _e______e__e__e__
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: se______e__e__ess
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: sel___lle__e__ess
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: sel_c_llec_e__ess
# You have 6 guesses left.
# Good guess! 'f' is in the word.
# Current word: selfc_llec_e__ess
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: selfcollec_e__ess
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: selfcollecte__ess
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: selfcollected_ess
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: selfcollectedness
# You have 6 guesses left.
# You won! The word was selfcollectedness.
# Good guess! 'u' is in the word.
# Current word: _u____u____u_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: _u_t_tu____u_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: _u_titu_i__u_
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: mu_titu_i__u_
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: multitu_i__u_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: multitudi__u_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: multitudin_u_
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: multitudinou_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: multitudinous
# You have 6 guesses left.
# You won! The word was multitudinous.
# Good guess! 'o' is in the word.
# Current word: _____o____o_____
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: _____on___on____
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: _____ona__ona___
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: _____ona__onall_
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: p____ona__onall_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: ps___ona__onall_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: pse__ona__onall_
# You have 6 guesses left.
# Good guess! 'u' is in the word.
# Current word: pseu_ona__onall_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: pseudona__onall_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: pseudonat_onall_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: pseudonationall_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: pseudonationally
# You have 6 guesses left.
# You won! The word was pseudonationally.
# Good guess! 'o' is in the word.
# Current word: __o_o_
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: p_o_o_
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: pro_o_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: proto_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: proton
# You have 6 guesses left.
# You won! The word was proton.
# Good guess! 'r' is in the word.
# Current word: r_____r
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: re___er
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: res__er
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: resa_er
# You have 6 guesses left.
# Good guess! 'w' is in the word.
# Current word: resawer
# You have 6 guesses left.
# You won! The word was resawer.
# Good guess! 'p' is in the word.
# Current word: p___p_______
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: pe__p__e____
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: pe_ip__e_i__
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: pe_ip_teti__
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: perip_teti__
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: peripateti__
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: peripatetic_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: peripatetics
# You have 6 guesses left.
# You won! The word was peripatetics.
# Good guess! 'a' is in the word.
# Current word: a_a__
# You have 6 guesses left.
# Good guess! 'w' is in the word.
# Current word: awa__
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: away_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: aways
# You have 6 guesses left.
# You won! The word was aways.
# Good guess! 'o' is in the word.
# Current word: __o___o__o______o__o__
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: d_od__o__o______o__o__
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: d_ode_o__o_e____o__o__
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: d_ode_oc_o_ec___o__o__
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: d_ode_oc_o_ecy__o__o_y
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: d_ode_oc_o_ecys_os_o_y
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: d_ode_oc_o_ecystosto_y
# You have 6 guesses left.
# Good guess! 'u' is in the word.
# Current word: duode_oc_o_ecystosto_y
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: duodenoc_o_ecystosto_y
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: duodenocho_ecystosto_y
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: duodenocholecystosto_y
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: duodenocholecystostomy
# You have 6 guesses left.
# You won! The word was duodenocholecystostomy.
# Good guess! 'p' is in the word.
# Current word: p_____p_________p______
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: p_____p__l______p___ll_
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: p____op__l_____op___ll_
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: p____oph_l___h_op___ll_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: p____ophil___h_opi__ll_
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: p____ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: ps___ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: pse__ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'u' is in the word.
# Current word: pseu_ophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: pseudophila__h_opi_all_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: pseudophilan_h_opi_all_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: pseudophilanth_opi_all_
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: pseudophilanthropi_all_
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: pseudophilanthropicall_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: pseudophilanthropically
# You have 6 guesses left.
# You won! The word was pseudophilanthropically.
# Good guess! 'm' is in the word.
# Current word: m_______
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: ma______
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: man_____
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: mand____
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: mande___
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: mandel__
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: mandeli_
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: mandelic
# You have 6 guesses left.
# You won! The word was mandelic.
# Good guess! 'p' is in the word.
# Current word: p___p_______
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: pe__p__e____
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: pe_ip__e_i__
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: pe_ip_teti__
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: perip_teti__
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: peripateti__
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: peripatetic_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: peripatetics
# You have 6 guesses left.
# You won! The word was peripatetics.
# Good guess! 't' is in the word.
# Current word: _____t____t______t____t______
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: _____t_i__t______t_i_it___i__
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: _____t_i_et___e_et_i_it___i_e
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: _____tri_et___e_etri_itr__i_e
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: _____tri_et___enetrinitr__ine
# You have 6 guesses left.
# Good guess! 'c' is in the word.
# Current word: c_c__tri_et___enetrinitr__ine
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: cyc__tri_et_y_enetrinitr__ine
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: cycl_tri_et_ylenetrinitr__ine
# You have 6 guesses left.
# Good guess! 'm' is in the word.
# Current word: cycl_trimet_ylenetrinitr_mine
# You have 6 guesses left.
# Good guess! 'o' is in the word.
# Current word: cyclotrimet_ylenetrinitr_mine
# You have 6 guesses left.
# Good guess! 'h' is in the word.
# Current word: cyclotrimethylenetrinitr_mine
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: cyclotrimethylenetrinitramine
# You have 6 guesses left.
# You won! The word was cyclotrimethylenetrinitramine.
# Good guess! 'o' is in the word.
# Current word: __o_o_
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: p_o_o_
# You have 6 guesses left.
# Good guess! 'r' is in the word.
# Current word: pro_o_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: proto_
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: proton
# You have 6 guesses left.
# You won! The word was proton.
# Good guess! 'o' is in the word.
# Current word: _____o____o_____
# You have 6 guesses left.
# Good guess! 'n' is in the word.
# Current word: _____on___on____
# You have 6 guesses left.
# Good guess! 'a' is in the word.
# Current word: _____ona__ona___
# You have 6 guesses left.
# Good guess! 'l' is in the word.
# Current word: _____ona__onall_
# You have 6 guesses left.
# Good guess! 'p' is in the word.
# Current word: p____ona__onall_
# You have 6 guesses left.
# Good guess! 's' is in the word.
# Current word: ps___ona__onall_
# You have 6 guesses left.
# Good guess! 'e' is in the word.
# Current word: pse__ona__onall_
# You have 6 guesses left.
# Good guess! 'u' is in the word.
# Current word: pseu_ona__onall_
# You have 6 guesses left.
# Good guess! 'd' is in the word.
# Current word: pseudona__onall_
# You have 6 guesses left.
# Good guess! 't' is in the word.
# Current word: pseudonat_onall_
# You have 6 guesses left.
# Good guess! 'i' is in the word.
# Current word: pseudonationall_
# You have 6 guesses left.
# Good guess! 'y' is in the word.
# Current word: pseudonationally
# You have 6 guesses left.
# You won! The word was pseudonationally.
# Accuracy: 99.40%
# 99.4
